# %%
from langchain_ollama import ChatOllama

# %%
model = ChatOllama(model="llama3.2:latest")
print("Model Ready")
response =model.invoke("Who is chief Minister of karnataka ?");
print(type(response))
print(response)
print(response.content)
# Out:
# Model Ready
# <class 'langchain_core.messages.ai.AIMessage'>
# content='The current Chief Minister of Karnataka is Basavaraj Bommai.' additional_kwargs={} response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-09-02T17:04:06.4180864Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1168283800, 'load_duration': 2136100, 'prompt_eval_count': 34, 'prompt_eval_duration': 91024000, 'eval_count': 14, 'eval_duration': 1067032999, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'} id='lc_run--01a06313-ec7c-7ca2-95f8-520a9fb78efe-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 34, 'output_tokens': 14, 'total_tokens': 48}
# The current Chief Minister of Karnataka is Basavaraj Bommai.
